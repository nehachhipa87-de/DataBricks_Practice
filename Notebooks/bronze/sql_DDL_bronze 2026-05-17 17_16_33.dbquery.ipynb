-- %%
CREATE OR REPLACE TABLE neha_catalog.bronze_schema.rawMonthlySales
(
    sale_id STRING, product STRING, category STRING, quantity STRING, price STRING, sale_date STRING, region STRING, ingest_ts TIMESTAMP
);

describe neha_catalog.bronze_schema.rawmonthlysales;

SELECT * FROM neha_catalog.bronze_schema.rawmonthlysales;

describe history neha_catalog.bronze_schema.rawmonthlysales;
