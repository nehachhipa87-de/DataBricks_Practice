-- %%
CREATE OR REPLACE TABLE neha_catalog.silver_schema.cleanedMonthlySales
(
    sale_id INTEGER, product STRING, category STRING, quantity INTEGER, price DOUBLE, sale_date date, region STRING, ingest_ts TIMESTAMP
);

describe neha_catalog.silver_schema.cleanedmonthlysales;
 
SELECT * FROM neha_catalog.silver_schema.cleanedMonthlySales;
