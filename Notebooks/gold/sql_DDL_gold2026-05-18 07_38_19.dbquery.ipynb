-- %%
CREATE OR REPLACE TABLE neha_catalog.gold_schema.RefinedMonthlySales
(
    sale_id INTEGER, product STRING, category STRING, quantity INTEGER, price DOUBLE, sale_date date, region STRING, ingest_ts TIMESTAMP, initial_load_ts TIMESTAMP,last_updt_ts TIMESTAMP
);

describe neha_catalog.gold_schema.RefinedMonthlySales;
 
SELECT * FROM neha_catalog.gold_schema.RefinedMonthlySales;
